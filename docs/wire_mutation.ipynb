# %%
import IO_map
import random
import networkx as nx
import matplotlib.pyplot as plt
from collections import defaultdict

"""
Wire can be in many groups: A wire can be on many linear paths
    - Every wire is initally in a group with it's parent and child modules
Wire can be in many loops: A wire can be on many looped paths
Groups contains {group_id : [modules in that group]}
    - Initially one group for every input and output pair 
    - Group id is initially the wire id, since each wire is in it's own group
Loops contains {loop_id : [modules in that loop]}

"""
class Fuzz_Run:
    def __init__(self, flattened_lib_path):
        random.seed(1)
        self.flattened_lib_path = flattened_lib_path
        io_map = IO_map.create_IO_map(flattened_lib_path)

        self.all_wires = io_map['bit_input'].copy()
        self.all_wires.update(io_map['bit_output']) # Single source of truth
        
        self.mod_IO = io_map['mod_IO']
        self.all_modules = io_map['mod_list']

        self.external_inputs = list(io_map['bit_input'].keys())
        self.external_outputs = list(io_map['bit_output'].keys()) # Unchanged will always output all outputs

        self.module_tree = {}
        for i in range(len(io_map['mod_list'])):
            module = io_map['mod_list'][i]
            self.module_tree[module] = {"depth" : 0, "tree":i, "children" : [], "parents":[], "loops":[]}

        self.loops = {}
        self.loop_set = set()
        
    def visualize_graph(self):
        G = nx.DiGraph()
        G.add_node("EXT_INPUT", color="green")
        G.add_node("EXT_OUTPUT", color="red")

        for mod in self.all_modules:
            G.add_node(mod, color="lightblue")

        edge_labels = {}
        edge_styles = {}

        for wire in self.all_wires.values():
            if wire.type == IO_map.Wire.Wire_Type.ITM:
                dst_port = wire.output[0] if wire.output else None
                if dst_port and "_input_" in dst_port:
                    dst_mod = dst_port.split("_input_")[0]
                    G.add_edge("EXT_INPUT", dst_mod)
                    edge_labels[("EXT_INPUT", dst_mod)] = f"w{wire.id}"
                    edge_styles[("EXT_INPUT", dst_mod)] = ("gray", "solid")

            elif wire.type == IO_map.Wire.Wire_Type.MTM:
                src_mod = wire.input
                if "_output_" not in src_mod:
                    src_mod = src_mod.split("_output_")[0]
                for dst in wire.output:
                    if dst == "output":
                        G.add_edge(src_mod, "EXT_OUTPUT")
                        edge_labels[(src_mod, "EXT_OUTPUT")] = f"w{wire.id}"
                        edge_styles[(src_mod, "EXT_OUTPUT")] = ("gray", "solid")
                    elif "_input_" in dst:
                        dst_mod = dst.split("_input_")[0]
                        G.add_edge(src_mod, dst_mod)
                        label = f"w{wire.id}"
                        edge_labels[(src_mod, dst_mod)] = label

                        # Style based on reg/cycle
                        if wire.reg:
                            edge_styles[(src_mod, dst_mod)] = ("red", "solid")
                        elif (self.module_tree[src_mod]["loops"]
                            or self.module_tree[dst_mod]["loops"]):
                            edge_styles[(src_mod, dst_mod)] = ("blue", "dashed")
                        else:
                            edge_styles[(src_mod, dst_mod)] = ("gray", "solid")

        pos = nx.spring_layout(G, seed=42)
        node_colors = [G.nodes[n].get("color", "white") for n in G.nodes()]
        nx.draw(G, pos, with_labels=True, node_color=node_colors,
                node_size=1000, font_size=8)

        # Draw edges with different colors & styles
        for (u, v), (color, style) in edge_styles.items():
            nx.draw_networkx_edges(G, pos, edgelist=[(u, v)],
                                edge_color=color,
                                style=style,
                                width=2 if color != "gray" else 1)

        nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=6)
        plt.title("Module Graph (Red=Reg, Blue=Cycle, Gray=Normal)")
        plt.show()

 
    def visualize_graph_no_ext_out(self):
        """
        Visualize the module graph without external outputs.
        - Red solid edges: wires with reg=True (registered).
        - Blue dashed edges: cycle edges (modules in self.loops).
        - Gray solid edges: normal wires.
        """
        G = nx.DiGraph()
        G.add_node("EXT_INPUT", color="green")

        for mod in self.all_modules:
            G.add_node(mod, color="lightblue")

        edge_labels = {}
        edge_styles = {}

        for wire in self.all_wires.values():
            if wire.type == IO_map.Wire.Wire_Type.ITM:
                dst_port = wire.output[0] if wire.output else None
                if dst_port and "_input_" in dst_port:
                    dst_mod = dst_port.split("_input_")[0]
                    G.add_edge("EXT_INPUT", dst_mod)
                    edge_labels[("EXT_INPUT", dst_mod)] = f"w{wire.id}"
                    edge_styles[("EXT_INPUT", dst_mod)] = ("gray", "solid")

            elif wire.type == IO_map.Wire.Wire_Type.MTM:
                src_mod = wire.input
                if "_output_" in src_mod:
                    src_mod = src_mod.split("_output_")[0]

                for dst in wire.output:
                    if dst == "output":
                        continue  # No external outputs in this view
                    if "_input_" in dst:
                        dst_mod = dst.split("_input_")[0]
                        G.add_edge(src_mod, dst_mod)
                        edge_labels[(src_mod, dst_mod)] = f"w{wire.id}"

                        # Style based on reg/cycle
                        if wire.reg:
                            edge_styles[(src_mod, dst_mod)] = ("red", "solid")
                        elif (self.module_tree[src_mod]["loops"]):
                            edge_styles[(src_mod, dst_mod)] = ("blue", "dashed")
                        else:
                            edge_styles[(src_mod, dst_mod)] = ("gray", "solid")

        pos = nx.spring_layout(G, seed=42)
        node_colors = [G.nodes[n].get("color", "white") for n in G.nodes()]
        nx.draw(G, pos, with_labels=True, node_color=node_colors,
                node_size=1000, font_size=8)

        # Draw edges with appropriate styles
        for (u, v), (color, style) in edge_styles.items():
            nx.draw_networkx_edges(G, pos, edgelist=[(u, v)],
                                edge_color=color,
                                style=style,
                                width=2 if color != "gray" else 1)

        nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=6)
        plt.title("Module Graph (No EXT Output) [Red=Reg, Blue=Cycle, Gray=Normal]")
        plt.show()

    def _mod_from_port(self, port_str):
        """Helper function to extract module name from a port string like 'adder_wrapper_input_3'."""
        if "_input_" in port_str:
            return port_str.split("_input_")[0]
        elif "_output_" in port_str:
            return port_str.split("_output_")[0]
        raise ValueError(f"Unrecognized port name format: {port_str}")
    
    def shift_module_depth_below(self, A: str, B: str, merge_trees: bool = False):
        """
        Shift the subtree rooted at module B so that B is at depth A.depth + 1.
        Always updates parent/child relationship: A → B.

        If merge_trees is False:
            - Requires A and B in the same tree.
            - Requires A.depth <= B.depth.
            - Shift happens only if A.depth == B.depth.
            - Only B and its descendants are shifted (not its parents).

        If merge_trees is True:
            - B and its entire subtree are shifted to A.depth + 1.
            - Tree ID of B, its descendants, and its parents are changed to A's tree.
        """
        if A not in self.module_tree or B not in self.module_tree:
            print(f"[Shift] One or both modules '{A}' and '{B}' do not exist.")
            return

        depth_A = self.module_tree[A]["depth"]
        depth_B = self.module_tree[B]["depth"]
        tree_A = self.module_tree[A]["tree"]
        tree_B = self.module_tree[B]["tree"]

        if not merge_trees:
            assert tree_A == tree_B, f"[Shift] Can't shift: '{A}' and '{B}' are in different trees."
            assert depth_A <= depth_B, f"[Shift] Can't shift: '{A}' is deeper than '{B}' in same tree."

            if depth_A != depth_B:
                print(f"[Shift] Skipped depth shift: '{A}' and '{B}' are not at the same depth.")
            else:
                # Shift B and descendants by +1
                queue = [B]
                visited = set()

                while queue:
                    current = queue.pop(0)
                    if current in visited:
                        continue
                    visited.add(current)

                    self.module_tree[current]["depth"] += 1

                    for child in self.module_tree[current]["children"]:
                        if child not in visited:
                            queue.append(child)

        else:
            # Calculate how much we need to shift B to be just below A
            delta = (depth_A + 1) - depth_B

            # Shift B and its descendants
            queue = [B]
            visited = set()

            while queue:
                current = queue.pop(0)
                if current in visited:
                    continue
                visited.add(current)

                self.module_tree[current]["depth"] += delta
                self.module_tree[current]["tree"] = tree_A

                for child in self.module_tree[current]["children"]:
                    if child not in visited:
                        queue.append(child)

            # Update all parents of B to tree_A
            parent_queue = list(self.module_tree[B]["parents"])
            seen_parents = set()

            while parent_queue:
                parent = parent_queue.pop()
                if parent in seen_parents:
                    continue
                seen_parents.add(parent)
                self.module_tree[parent]["tree"] = tree_A
                parent_queue.extend(self.module_tree[parent]["parents"])

        # Always update parent/child relationship
        if B not in self.module_tree[A]["children"]:
            self.module_tree[A]["children"].append(B)
        if A not in self.module_tree[B]["parents"]:
            self.module_tree[B]["parents"].append(A)

        print(f"[Shift] Parent/child set: '{A}' → '{B}'. Tree merged: {merge_trees}")

    def linear_rewire(self):
        """
        Rewire one external output (MTO/MTM) to an internal input (ITM).
        Ensures mod_IO and all_wires stay consistent after rewiring.
        Updates wire type:
        - MTO → MTM if adding a module connection
        - MTM → MTO if only 'output' remains after removing a connection
        Rules:
        - Never rewire registered wires (reg=True).
        - Never rewire if:
            * One module is parent/child of the other (directly).
            * Both modules are already in loops.
            * Rewiring would reverse an existing parent-child hierarchy
                (e.g., making a parent become a child, which increases depth indefinitely).
        """
        if not self.external_outputs:
            print("[Rewire] No external outputs to rewire.")
            return

        for _ in range(len(self.external_outputs)):
            output_wire_id = self.external_outputs[random.randrange(len(self.external_outputs))]
            output_wire = self.all_wires[output_wire_id]
            assert output_wire.type in (IO_map.Wire.Wire_Type.MTM, IO_map.Wire.Wire_Type.MTO)

            output_port = output_wire.input
            assert "_output_" in output_port

            output_mod = output_port.split("_output_")[0]

            # Skip if this wire is registered and belongs to a loop
            if output_wire.reg and output_mod in self.loop_set:
                continue

            output_tree = self.module_tree[output_mod]["tree"]
            output_depth = self.module_tree[output_mod]["depth"]

            for _ in range(len(self.all_modules)):
                target_mod = self.all_modules[random.randrange(len(self.all_modules))]
                if target_mod == output_mod:
                    continue

                target_tree = self.module_tree[target_mod]["tree"]
                target_depth = self.module_tree[target_mod]["depth"]

                # --- New Checks ---
                # 1. Skip if both modules are already in loops
                if output_mod in self.loop_set and target_mod in self.loop_set:
                    continue

                # 2. Skip if direct parent-child already exists
                if target_mod in self.module_tree[output_mod]["parents"] or \
                target_mod in self.module_tree[output_mod]["children"] or \
                output_mod in self.module_tree[target_mod]["parents"] or \
                output_mod in self.module_tree[target_mod]["children"]:
                    continue

                # 3. Skip if this rewiring would reverse hierarchy (make parent become child)
                # If target is an ancestor of output_mod, rewiring would make parent into child
                def is_ancestor(ancestor, descendant):
                    visited, stack = set(), [ancestor]
                    while stack:
                        cur = stack.pop()
                        if cur == descendant:
                            return True
                        for p in self.module_tree[cur]["parents"]:
                            if p not in visited:
                                visited.add(p)
                                stack.append(p)
                    return False

                if is_ancestor(target_mod, output_mod):
                    continue

                # Skip if would create illegal cycle by depth rule
                if target_tree == output_tree and target_depth < output_depth:
                    continue

                target_inputs = list(self.mod_IO[target_mod]['inputs'])
                if not target_inputs:
                    continue

                target_wire_id = target_inputs[random.randrange(len(target_inputs))]
                target_wire = self.all_wires[target_wire_id]

                # Skip if target wire is registered and looped
                if target_wire.reg and target_mod in self.loop_set:
                    continue

                ports = [p for p in target_wire.output if p.startswith(target_mod)]
                if not ports:
                    continue
                target_port = ports[0]

                # ===============================
                # CONSISTENT REWIRING UPDATES
                # ===============================
                output_wire.output.append(target_port)

                # Update type if previously MTO (now drives a module too)
                if output_wire.type == IO_map.Wire.Wire_Type.MTO:
                    output_wire.type = IO_map.Wire.Wire_Type.MTM

                if output_wire.id not in self.mod_IO[target_mod]['inputs']:
                    self.mod_IO[target_mod]['inputs'].add(output_wire.id)

                # Disconnect target wire only if not registered
                if not (target_wire.reg and target_mod in self.loop_set):
                    if target_port in target_wire.output:
                        target_wire.output.remove(target_port)

                    still_drives_module = any(p.startswith(f"{target_mod}_input_") for p in target_wire.output)
                    if not still_drives_module and target_wire_id in self.mod_IO[target_mod]['inputs']:
                        self.mod_IO[target_mod]['inputs'].remove(target_wire_id)

                    # Update type if now only drives 'output'
                    if target_wire.type == IO_map.Wire.Wire_Type.MTM and target_wire.output == ['output']:
                        target_wire.type = IO_map.Wire.Wire_Type.MTO

                    # Remove ITM wire if fully disconnected
                    if target_wire.type == IO_map.Wire.Wire_Type.ITM and not target_wire.output:
                        if target_wire.id in self.all_wires:
                            self.all_wires.pop(target_wire.id)
                        if target_wire.id in self.external_inputs:
                            self.external_inputs.remove(target_wire.id)

                merge_trees = target_tree != output_tree
                self.shift_module_depth_below(output_mod, target_mod, merge_trees)

                assert output_wire.id in self.mod_IO[target_mod]['inputs'], \
                    f"[Rewire-Error] {output_wire.id} missing from {target_mod} inputs after rewiring"

                print(f"[Rewire] {output_mod} → {target_mod} via {target_port}")
                return

        print("[Rewire] No valid rewiring opportunity found.")



    def cyclical_rewire(self):
        """
        Rewire exactly ONE wire to create a cycle (back-edge).
        - Updates all modules in the cycle within module_tree.
        - Never removes or alters registered wires (reg=True).
        - MTO ↔ MTM transitions handled consistently.
        """
        if not self.external_outputs:
            print("[Cyclical-Rewire] No external outputs to rewire.")
            return

        for _ in range(len(self.external_outputs)):
            output_wire_id = self.external_outputs[random.randrange(len(self.external_outputs))]
            output_wire = self.all_wires[output_wire_id]
            assert output_wire.type in (IO_map.Wire.Wire_Type.MTM, IO_map.Wire.Wire_Type.MTO)

            output_port = output_wire.input
            assert "_output_" in output_port

            output_mod = output_port.split("_output_")[0]

            # Skip if this output_wire is already registered and looped (never modify existing registered wires)
            if output_wire.reg and output_mod in self.loop_set:
                continue

            output_tree = self.module_tree[output_mod]["tree"]
            output_depth = self.module_tree[output_mod]["depth"]

            for _ in range(len(self.all_modules)):
                target_mod = self.all_modules[random.randrange(len(self.all_modules))]
                if target_mod == output_mod:
                    continue

                target_tree = self.module_tree[target_mod]["tree"]
                target_depth = self.module_tree[target_mod]["depth"]

                # Skip if would create illegal loop
                if target_tree != output_tree or target_depth >= output_depth:
                    continue

                target_inputs = list(self.mod_IO[target_mod]['inputs'])
                if not target_inputs:
                    continue

                target_wire_id = target_inputs[random.randrange(len(target_inputs))]
                target_wire = self.all_wires[target_wire_id]

                # Never modify existing registered wires in loops
                if target_wire.reg and target_mod in self.loop_set:
                    continue

                ports = [p for p in target_wire.output if p.startswith(target_mod)]
                if not ports:
                    continue
                target_port = ports[0]

                try:
                    cycle = self._construct_cycle(target_mod, output_mod)
                except RuntimeError:
                    continue

                # Skip if any module in cycle already looped
                if any(m in self.loop_set for m in cycle):
                    continue

                # ===============================
                # CONSISTENT REWIRING UPDATES
                # ===============================
                output_wire.output.append(target_port)
                output_wire.reg = True  # The source module’s outputs must all be registered now

                # Update type if previously MTO (now drives a module too)
                if output_wire.type == IO_map.Wire.Wire_Type.MTO:
                    output_wire.type = IO_map.Wire.Wire_Type.MTM

                if output_wire.id not in self.mod_IO[target_mod]['inputs']:
                    self.mod_IO[target_mod]['inputs'].add(output_wire.id)

                # Disconnect old wire only if not registered
                if not (target_wire.reg and target_mod in self.loop_set):
                    if target_port in target_wire.output:
                        target_wire.output.remove(target_port)

                    still_drives_module = any(p.startswith(f"{target_mod}_input_") for p in target_wire.output)
                    if not still_drives_module and target_wire_id in self.mod_IO[target_mod]['inputs']:
                        self.mod_IO[target_mod]['inputs'].remove(target_wire_id)

                    # Update type if now only drives 'output'
                    if target_wire.type == IO_map.Wire.Wire_Type.MTM and target_wire.output == ['output']:
                        target_wire.type = IO_map.Wire.Wire_Type.MTO

                    # Remove ITM wire if fully disconnected
                    if target_wire.type == IO_map.Wire.Wire_Type.ITM and not target_wire.output:
                        if target_wire.id in self.all_wires:
                            self.all_wires.pop(target_wire.id)
                        if target_wire.id in self.external_inputs:
                            self.external_inputs.remove(target_wire.id)

                if output_mod not in self.module_tree[target_mod]["parents"]:
                    self.module_tree[target_mod]["parents"].append(output_mod)
                if target_mod not in self.module_tree[output_mod]["children"]:
                    self.module_tree[output_mod]["children"].append(target_mod)

                # ===============================
                # LOOP REGISTRATION UPDATES
                # ===============================
                loop_id = f"loop_{len(self.loops)}"
                self.loops[loop_id] = cycle

                # Update ALL modules in the cycle
                for m in cycle:
                    self.module_tree[m]["loops"] = [loop_id]
                self.loop_set.update(cycle)

                # Mark ALL outputs of the source module as registered
                for w in self.all_wires.values():
                    if w.type in (IO_map.Wire.Wire_Type.MTM, IO_map.Wire.Wire_Type.MTO) and w.input.startswith(output_mod):
                        w.reg = True

                assert output_wire.id in self.mod_IO[target_mod]['inputs'], \
                    f"[Cyclical-Rewire-Error] {output_wire.id} missing from {target_mod} inputs after rewiring"

                print(f"[Cyclical-Rewire] {output_mod} → {target_mod} | Cycle: {cycle} | "
                    f"All outputs of {output_mod} marked reg=True")
                return

        print("[Cyclical-Rewire] No valid cyclical rewiring opportunity found.")


    def _construct_cycle(self, parent_mod, child_mod):
        """
        Finds the existing forward DAG path from parent_mod → ... → child_mod,
        ignoring modules already in loops.
        Returns a list of modules in cycle order: [parent_mod, ..., child_mod, parent_mod].
        """
        path = []
        found = False

        def dfs(current, target, visited):
            nonlocal found
            if found:
                return
            visited.append(current)

            if current == target:
                path.extend(visited)
                found = True
                return

            for child in self.module_tree[current]["children"]:
                if child in visited or child in self.loop_set:
                    continue
                dfs(child, target, visited.copy())

        dfs(parent_mod, child_mod, [])
        if not found:
            raise RuntimeError(f"[Cycle-Error] No valid DAG path from {parent_mod} to {child_mod}")

        path.append(parent_mod)
        return path

    def generate_top_module(self, top_name="top", output_path=""):
        """
        Generate a top-level Verilog module connecting all module_wrappers.
        Explicitly separates MTM and MTO wires:
        - MTM: drives modules and may also drive 'output'.
        - MTO: only drives 'output'.
        Handles reg=True (looped modules) and skips stale wires.
        """

        ext_inputs = self.external_inputs
        ext_outputs = self.external_outputs
        wire_map = self.all_wires
        mod_IO = self.mod_IO

        ext_in_pos = {wid: i for i, wid in enumerate(ext_inputs)}
        ext_out_pos = {wid: j for j, wid in enumerate(ext_outputs)}

        # Proper input/output ordering based on port names
        mod_in_order = {}
        for mod, io in mod_IO.items():
            def port_index(wid):
                ports = [p for p in self.all_wires[wid].output if p.startswith(mod)]
                return int(ports[0].split("_input_")[1]) if ports else 9999
            mod_in_order[mod] = sorted(io['inputs'], key=port_index)

        mod_out_order = {}
        for mod, io in mod_IO.items():
            def port_index_out(wid):
                return int(self.all_wires[wid].input.split("_output_")[1])
            mod_out_order[mod] = sorted(io['outputs'], key=port_index_out)

        mod_in_width = {mod: len(bits) for mod, bits in mod_in_order.items()}
        mod_out_width = {mod: len(bits) for mod, bits in mod_out_order.items()}

        lines = []
        lines.append("// Auto-generated Top Module for flattened IO")

        # Include wrapper files
        for mod in sorted(self.all_modules):
            lines.append(f"`include \"{mod}.sv\"")
        lines.append("")

        # Top module declaration
        lines.append(f"module {top_name} (")
        if ext_inputs:
            lines.append("    input  wire clk,")
            lines.append(f"    input  wire [{len(ext_inputs)-1}:0] in_flat,")
        else:
            lines.append("    input wire clk,  // no external inputs")
        if ext_outputs:
            lines.append(f"    output wire [{len(ext_outputs)-1}:0] out_flat")
        else:
            lines.append("    // no external outputs")
        lines.append(");\n")

        # Per-module I/O buses
        lines.append("// Per-module I/O buses")
        for mod in sorted(self.all_modules):
            inW, outW = mod_in_width[mod], mod_out_width[mod]
            if inW:
                lines.append(f"wire [{inW-1}:0] {mod}_in_flat;")
            else:
                lines.append(f"// {mod} has no inputs")
            if outW:
                lines.append(f"wire [{outW-1}:0] {mod}_out_flat;")
            else:
                lines.append(f"// {mod} has no outputs")
        lines.append("")

        # Registered modules
        regged_modules = {
            w.input.split("_output_")[0]
            for w in wire_map.values()
            if w.type == IO_map.Wire.Wire_Type.MTM and w.reg
        }

        if regged_modules:
            lines.append("// Registered output shadows for looped modules")
            for mod in sorted(regged_modules):
                outW = mod_out_width[mod]
                lines.append(f"reg [{outW-1}:0] {mod}_out_reg;")
                lines.append(f"always @(posedge clk) {mod}_out_reg <= {mod}_out_flat;")
            lines.append("")
            lines.append("// Initialize registered outputs to zero for simulation")
            lines.append("initial begin")
            for mod in sorted(regged_modules):
                outW = mod_out_width[mod]
                lines.append(f"    {mod}_out_reg = {outW}'b0;")
            lines.append("end\n")

        # External inputs
        if ext_inputs:
            lines.append("// External inputs to module inputs")
            for wire_id in ext_inputs:
                if wire_id not in wire_map:
                    continue
                wire = wire_map[wire_id]
                if not wire.output or wire.type != IO_map.Wire.Wire_Type.ITM:
                    continue
                dst = wire.output[0]
                mod = self._mod_from_port(dst)
                bitidx = mod_in_order[mod].index(wire_id)
                lines.append(f"assign {mod}_in_flat[{bitidx}] = in_flat[{ext_in_pos[wire_id]}];")
            lines.append("")

        # Internal MTM connections
        lines.append("// Internal MTM connections (module-to-module)")
        for wire in wire_map.values():
            if wire.type != IO_map.Wire.Wire_Type.MTM:
                continue

            src_mod = wire.input.split("_output_")[0]
            src_bit = mod_out_order[src_mod].index(wire.id)

            for dst in wire.output:
                if dst == "output":
                    continue
                dst_mod = self._mod_from_port(dst)
                dst_bit = mod_in_order[dst_mod].index(
                    next(wid for wid in mod_IO[dst_mod]['inputs'] if dst in wire_map[wid].output)
                )
                if src_mod in regged_modules:
                    lines.append(f"assign {dst_mod}_in_flat[{dst_bit}] = {src_mod}_out_reg[{src_bit}];")
                else:
                    lines.append(f"assign {dst_mod}_in_flat[{dst_bit}] = {src_mod}_out_flat[{src_bit}];")
        lines.append("")

        # External outputs (both MTO-only and MTM wires)
        if ext_outputs:
            lines.append("// External outputs (MTO + MTM wires)")
            for wire_id in ext_outputs:
                if wire_id not in wire_map:
                    continue
                wire = wire_map[wire_id]
                if wire.type not in (IO_map.Wire.Wire_Type.MTO, IO_map.Wire.Wire_Type.MTM):
                    continue

                mod = wire.input.split("_output_")[0]
                bitidx = mod_out_order[mod].index(wire_id)

                # MTM modules may be registered, MTO never is
                if mod in regged_modules:
                    lines.append(f"assign out_flat[{ext_out_pos[wire_id]}] = {mod}_out_reg[{bitidx}];")
                else:
                    lines.append(f"assign out_flat[{ext_out_pos[wire_id]}] = {mod}_out_flat[{bitidx}];")
            lines.append("")

        # Instantiate modules
        lines.append("// Instantiate all module wrappers")
        for mod in sorted(self.all_modules):
            inW, outW = mod_in_width[mod], mod_out_width[mod]
            if not (inW or outW):
                lines.append(f"// skip {mod}: no I/O")
                continue
            lines.append(f"{mod} u_{mod} (")
            ports = []
            if inW:
                ports.append(f".in_flat({mod}_in_flat)")
            if outW:
                ports.append(f".out_flat({mod}_out_flat)")
            for i, p in enumerate(ports):
                comma = "," if i < len(ports)-1 else ""
                lines.append(f"    {p}{comma}")
            lines.append(");")
        lines.append("endmodule")

        # Write to file
        final = "\n".join(lines)
        with open(f"{output_path}{top_name}.sv", "w") as output_file:
            output_file.write(final)

        return final



    def verify_consistency(self, verbose=True):
        """
        Verify consistency between self.mod_IO and self.all_wires.
        Checks:
        1. Every wire ID in mod_IO[mod]['inputs'] actually exists in all_wires and drives that module.
        2. Every wire in all_wires whose output drives a module appears in mod_IO for that module.
        Prints all inconsistencies found.
        Returns True if consistent, False otherwise.
        """

        consistent = True

        # 1. Check mod_IO → all_wires consistency
        for mod, io in self.mod_IO.items():
            for wid in list(io['inputs']):
                if wid not in self.all_wires:
                    consistent = False
                    if verbose:
                        print(f"[Consistency-Error] Wire {wid} listed in mod_IO[{mod}] but missing in all_wires.")
                    continue

                wire = self.all_wires[wid]
                drives_mod = any(p.startswith(f"{mod}_input_") for p in wire.output)
                if not drives_mod:
                    consistent = False
                    if verbose:
                        print(f"[Consistency-Error] Wire {wid} in mod_IO[{mod}] does not drive any {mod}_input_ ports. "
                            f"Outputs: {wire.output}")

        # 2. Check all_wires → mod_IO consistency
        for wid, wire in self.all_wires.items():
            for port in wire.output:
                if port == "output" or "_input_" not in port:
                    continue
                dst_mod = port.split("_input_")[0]
                if wid not in self.mod_IO[dst_mod]['inputs']:
                    consistent = False
                    if verbose:
                        print(f"[Consistency-Error] Wire {wid} drives {dst_mod} (port {port}) "
                            f"but is missing in mod_IO[{dst_mod}]['inputs'].")

        if verbose:
            if consistent:
                print("[Consistency] mod_IO and all_wires are consistent ✅")
            else:
                print("[Consistency] Inconsistencies detected ❌")

        return consistent

# %%
test_fuzz = Fuzz_Run("/opt/module-fuzz/rewiring/test_library_structured/flattened")

# %%
test_fuzz.linear_rewire()
test_fuzz.cyclical_rewire()
test_fuzz.linear_rewire()
for i in range(0, 13):
    test_fuzz.cyclical_rewire()
    test_fuzz.generate_top_module()
    print(test_fuzz.verify_consistency())

test_fuzz.visualize_graph_no_ext_out()
print(test_fuzz.verify_consistency())
test_fuzz.all_wires
# Out:
# [Shift] Parent/child set: 'const_nested_wrapper' → 'const_concat_repl_wrapper'. Tree merged: False
# [Rewire] const_nested_wrapper → const_concat_repl_wrapper via const_concat_repl_wrapper_input_7
# [Cyclical-Rewire] No valid cyclical rewiring opportunity found.
# [Shift] Skipped depth shift: 'const_partselect_wrapper' and 'const_reduce_wrapper' are not at the same depth.
# [Shift] Parent/child set: 'const_partselect_wrapper' → 'const_reduce_wrapper'. Tree merged: False
# [Rewire] const_partselect_wrapper → const_reduce_wrapper via const_reduce_wrapper_input_2
# [Cyclical-Rewire] No valid cyclical rewiring opportunity found.
# [Consistency] mod_IO and all_wires are consistent ✅
# True
# [Cyclical-Rewire] No valid cyclical rewiring opportunity found.
# [Consistency] mod_IO and all_wires are consistent ✅
# True
# [Cyclical-Rewire] No valid cyclical rewiring opportunity found.
# [Consistency] mod_IO and all_wires are consistent ✅
# True
# [Cyclical-Rewire] No valid cyclical rewiring opportunity found.
# [Consistency] mod_IO and all_wires are consistent ✅
# True
# [Cyclical-Rewire] No valid cyclical rewiring opportunity found.
# [Consistency] mod_IO and all_wires are consistent ✅
# True
# [Cyclical-Rewire] No valid cyclical rewiring opportunity found.
# [Consistency] mod_IO and all_wires are consistent ✅
# True
# [Cyclical-Rewire] No valid cyclical rewiring opportunity found.
# [Consistency] mod_IO and all_wires are consistent ✅
# True
# [Cyclical-Rewire] No valid cyclical rewiring opportunity found.
# [Consistency] mod_IO and all_wires are consistent ✅
# True
# [Cyclical-Rewire] No valid cyclical rewiring opportunity found.
# [Consistency] mod_IO and all_wires are consistent ✅
# True
# [Cyclical-Rewire] No valid cyclical rewiring opportunity found.
# [Consistency] mod_IO and all_wires are consistent ✅
# True
# [Cyclical-Rewire] No valid cyclical rewiring opportunity found.
# [Consistency] mod_IO and all_wires are consistent ✅
# True
# [Cyclical-Rewire] No valid cyclical rewiring opportunity found.
# [Consistency] mod_IO and all_wires are consistent ✅
# True
# [Cyclical-Rewire] No valid cyclical rewiring opportunity found.
# [Consistency] mod_IO and all_wires are consistent ✅
# True
# [Consistency] mod_IO and all_wires are consistent ✅
# True
# {0: Wire(id=0, in='input', out=['const_arith_wrapper_input_0'], reg=False),
#  1: Wire(id=1, in='input', out=['const_arith_wrapper_input_1'], reg=False),
#  2: Wire(id=2, in='input', out=['const_arith_wrapper_input_2'], reg=False),
#  3: Wire(id=3, in='input', out=['const_arith_wrapper_input_3'], reg=False),
#  4: Wire(id=4, in='input', out=['const_arith_wrapper_input_4'], reg=False),
#  5: Wire(id=5, in='input', out=['const_arith_wrapper_input_5'], reg=False),
#  7: Wire(id=7, in='input', out=['const_arith_wrapper_input_7'], reg=False),
#  8: Wire(id=8, in='input', out=['const_arith_wrapper_input_8'], reg=False),
#  9: Wire(id=9, in='input', out=['const_arith_wrapper_input_9'], reg=False),
#  10: Wire(id=10, in='input', out=['const_arith_wrapper_input_10'], reg=False),
#  11: Wire(id=11, in='input', out=['const_arith_wrapper_input_11'], reg=False),
#  12: Wire(id=12, in='input', out=['const_arith_wrapper_input_12'], reg=False),
#  13: Wire(id=13, in='input', out=['const_arith_wrapper_input_13'], reg=False),
#  14: Wire(id=14, in='input', out=['const_arith_wrapper_input_14'], reg=False),
#  15: Wire(id=15, in='input', out=['const_arith_wrapper_input_15'], reg=False),
#  58: Wire(id=58, in='input', out=['const_shift_wrapper_input_2'], reg=False),
#  59: Wire(id=59, in='input', out=['const_shift_wrapper_input_3'], reg=False),
#  60: Wire(id=60, in='input', out=['const_shift_wrapper_input_4'], reg=False),
#  61: Wire(id=61, in='input', out=['const_shift_wrapper_input_5'], reg=False),
#  62: Wire(id=62, in='input', out=['const_shift_wrapper_input_6'], reg=False),
#  63: Wire(id=63, in='input', out=['const_shift_wrapper_input_7'], reg=False),
#  64: Wire(id=64, in='input', out=['const_shift_wrapper_input_8'], reg=False),
#  65: Wire(id=65, in='input', out=['const_shift_wrapper_input_9'], reg=False),
#  66: Wire(id=66, in='input', out=['const_shift_wrapper_input_10'], reg=False),
#  91: Wire(id=91, in='input', out=['const_nested_wrapper_input_0'], reg=False),
#  92: Wire(id=92, in='input', out=['const_nested_wrapper_input_1'], reg=False),
#  93: Wire(id=93, in='input', out=['const_nested_wrapper_input_2'], reg=False),
#  94: Wire(id=94, in='input', out=['const_nested_wrapper_input_3'], reg=False),
#  95: Wire(id=95, in='input', out=['const_nested_wrapper_input_4'], reg=False),
#  96: Wire(id=96, in='input', out=['const_nested_wrapper_input_5'], reg=False),
#  97: Wire(id=97, in='input', out=['const_nested_wrapper_input_6'], reg=False),
#  98: Wire(id=98, in='input', out=['const_nested_wrapper_input_7'], reg=False),
#  99: Wire(id=99, in='input', out=['const_nested_wrapper_input_8'], reg=False),
#  100: Wire(id=100, in='input', out=['const_nested_wrapper_input_9'], reg=False),
#  101: Wire(id=101, in='input', out=['const_nested_wrapper_input_10'], reg=False),
#  103: Wire(id=103, in='input', out=['const_nested_wrapper_input_12'], reg=False),
#  104: Wire(id=104, in='input', out=['const_nested_wrapper_input_13'], reg=False),
#  105: Wire(id=105, in='input', out=['const_nested_wrapper_input_14'], reg=False),
#  106: Wire(id=106, in='input', out=['const_nested_wrapper_input_15'], reg=False),
#  107: Wire(id=107, in='input', out=['const_nested_wrapper_input_16'], reg=False),
#  108: Wire(id=108, in='input', out=['const_nested_wrapper_input_17'], reg=False),
#  109: Wire(id=109, in='input', out=['const_nested_wrapper_input_18'], reg=False),
#  110: Wire(id=110, in='input', out=['const_nested_wrapper_input_19'], reg=False),
#  111: Wire(id=111, in='input', out=['const_nested_wrapper_input_20'], reg=False),
#  112: Wire(id=112, in='input', out=['const_nested_wrapper_input_21'], reg=False),
#  113: Wire(id=113, in='input', out=['const_nested_wrapper_input_22'], reg=False),
#  114: Wire(id=114, in='input', out=['const_nested_wrapper_input_23'], reg=False),
#  115: Wire(id=115, in='input', out=['const_nested_wrapper_input_24'], reg=False),
#  116: Wire(id=116, in='input', out=['const_nested_wrapper_input_25'], reg=False),
#  117: Wire(id=117, in='input', out=['const_nested_wrapper_input_26'], reg=False),
#  126: Wire(id=126, in='input', out=['const_partselect_wrapper_input_0'], reg=False),
#  127: Wire(id=127, in='input', out=['const_partselect_wrapper_input_1'], reg=False),
#  128: Wire(id=128, in='input', out=['const_partselect_wrapper_input_2'], reg=False),
#  129: Wire(id=129, in='input', out=['const_partselect_wrapper_input_3'], reg=False),
#  130: Wire(id=130, in='input', out=['const_partselect_wrapper_input_4'], reg=False),
#  131: Wire(id=131, in='input', out=['const_partselect_wrapper_input_5'], reg=False),
#  132: Wire(id=132, in='input', out=['const_partselect_wrapper_input_6'], reg=False),
#  134: Wire(id=134, in='input', out=['const_partselect_wrapper_input_8'], reg=False),
#  135: Wire(id=135, in='input', out=['const_partselect_wrapper_input_9'], reg=False),
#  136: Wire(id=136, in='input', out=['const_partselect_wrapper_input_10'], reg=False),
#  138: Wire(id=138, in='input', out=['const_partselect_wrapper_input_12'], reg=False),
#  139: Wire(id=139, in='input', out=['const_partselect_wrapper_input_13'], reg=False),
#  142: Wire(id=142, in='input', out=['const_partselect_wrapper_input_16'], reg=False),
#  143: Wire(id=143, in='input', out=['const_partselect_wrapper_input_17'], reg=False),
#  144: Wire(id=144, in='input', out=['const_partselect_wrapper_input_18'], reg=False),
#  145: Wire(id=145, in='input', out=['const_partselect_wrapper_input_19'], reg=False),
#  154: Wire(id=154, in='input', out=['const_compare_wrapper_input_0'], reg=False),
#  156: Wire(id=156, in='input', out=['const_compare_wrapper_input_2'], reg=False),
#  157: Wire(id=157, in='input', out=['const_compare_wrapper_input_3'], reg=False),
#  158: Wire(id=158, in='input', out=['const_compare_wrapper_input_4'], reg=False),
#  159: Wire(id=159, in='input', out=['const_compare_wrapper_input_5'], reg=False),
#  160: Wire(id=160, in='input', out=['const_compare_wrapper_input_6'], reg=False),
#  161: Wire(id=161, in='input', out=['const_compare_wrapper_input_7'], reg=False),
#  162: Wire(id=162, in='input', out=['const_compare_wrapper_input_8'], reg=False),
#  163: Wire(id=163, in='input', out=['const_compare_wrapper_input_9'], reg=False),
#  164: Wire(id=164, in='input', out=['const_compare_wrapper_input_10'], reg=False),
#  165: Wire(id=165, in='input', out=['const_compare_wrapper_input_11'], reg=False),
#  166: Wire(id=166, in='input', out=['const_compare_wrapper_input_12'], reg=False),
#  167: Wire(id=167, in='input', out=['const_compare_wrapper_input_13'], reg=False),
#  168: Wire(id=168, in='input', out=['const_compare_wrapper_input_14'], reg=False),
#  169: Wire(id=169, in='input', out=['const_compare_wrapper_input_15'], reg=False),
#  170: Wire(id=170, in='input', out=['const_compare_wrapper_input_16'], reg=False),
#  172: Wire(id=172, in='input', out=['const_compare_wrapper_input_18'], reg=False),
#  173: Wire(id=173, in='input', out=['const_compare_wrapper_input_19'], reg=False),
#  174: Wire(id=174, in='input', out=['const_compare_wrapper_input_20'], reg=False),
#  175: Wire(id=175, in='input', out=['const_compare_wrapper_input_21'], reg=False),
#  176: Wire(id=176, in='input', out=['const_compare_wrapper_input_22'], reg=False),
#  177: Wire(id=177, in='input', out=['const_compare_wrapper_input_23'], reg=False),
#  186: Wire(id=186, in='input', out=['const_reduce_wrapper_input_0'], reg=False),
#  187: Wire(id=187, in='input', out=['const_reduce_wrapper_input_1'], reg=False),
#  196: Wire(id=196, in='input', out=['const_concat_repl_wrapper_input_0'], reg=False),
#  197: Wire(id=197, in='input', out=['const_concat_repl_wrapper_input_1'], reg=False),
#  198: Wire(id=198, in='input', out=['const_concat_repl_wrapper_input_2'], reg=False),
#  199: Wire(id=199, in='input', out=['const_concat_repl_wrapper_input_3'], reg=False),
#  200: Wire(id=200, in='input', out=['const_concat_repl_wrapper_input_4'], reg=False),
#  201: Wire(id=201, in='input', out=['const_concat_repl_wrapper_input_5'], reg=False),
#  202: Wire(id=202, in='input', out=['const_concat_repl_wrapper_input_6'], reg=False),
#  205: Wire(id=205, in='input', out=['const_concat_repl_wrapper_input_9'], reg=False),
#  229: Wire(id=229, in='input', out=['const_conditional_wrapper_input_1'], reg=False),
#  230: Wire(id=230, in='input', out=['const_conditional_wrapper_input_2'], reg=False),
#  231: Wire(id=231, in='input', out=['const_conditional_wrapper_input_3'], reg=False),
#  232: Wire(id=232, in='input', out=['const_conditional_wrapper_input_4'], reg=False),
#  233: Wire(id=233, in='input', out=['const_conditional_wrapper_input_5'], reg=False),
#  234: Wire(id=234, in='input', out=['const_conditional_wrapper_input_6'], reg=False),
#  235: Wire(id=235, in='input', out=['const_conditional_wrapper_input_7'], reg=False),
#  236: Wire(id=236, in='input', out=['const_conditional_wrapper_input_8'], reg=False),
#  237: Wire(id=237, in='input', out=['const_conditional_wrapper_input_9'], reg=False),
#  238: Wire(id=238, in='input', out=['const_conditional_wrapper_input_10'], reg=False),
#  239: Wire(id=239, in='input', out=['const_conditional_wrapper_input_11'], reg=False),
#  240: Wire(id=240, in='input', out=['const_conditional_wrapper_input_12'], reg=False),
#  242: Wire(id=242, in='input', out=['const_conditional_wrapper_input_14'], reg=False),
#  243: Wire(id=243, in='input', out=['const_conditional_wrapper_input_15'], reg=False),
#  244: Wire(id=244, in='input', out=['const_conditional_wrapper_input_16'], reg=False),
#  246: Wire(id=246, in='input', out=['const_conditional_wrapper_input_18'], reg=False),
#  247: Wire(id=247, in='input', out=['const_conditional_wrapper_input_19'], reg=False),
#  248: Wire(id=248, in='input', out=['const_conditional_wrapper_input_20'], reg=False),
#  249: Wire(id=249, in='input', out=['const_conditional_wrapper_input_21'], reg=False),
#  250: Wire(id=250, in='input', out=['const_conditional_wrapper_input_22'], reg=False),
#  251: Wire(id=251, in='input', out=['const_conditional_wrapper_input_23'], reg=False),
#  252: Wire(id=252, in='input', out=['const_conditional_wrapper_input_24'], reg=False),
#  253: Wire(id=253, in='input', out=['const_conditional_wrapper_input_25'], reg=False),
#  254: Wire(id=254, in='input', out=['const_conditional_wrapper_input_26'], reg=False),
#  255: Wire(id=255, in='input', out=['const_conditional_wrapper_input_27'], reg=False),
#  256: Wire(id=256, in='input', out=['const_conditional_wrapper_input_28'], reg=False),
#  257: Wire(id=257, in='input', out=['const_conditional_wrapper_input_29'], reg=False),
#  258: Wire(id=258, in='input', out=['const_conditional_wrapper_input_30'], reg=False),
#  259: Wire(id=259, in='input', out=['const_conditional_wrapper_input_31'], reg=False),
#  260: Wire(id=260, in='input', out=['const_conditional_wrapper_input_32'], reg=False),
#  261: Wire(id=261, in='input', out=['const_conditional_wrapper_input_33'], reg=False),
#  286: Wire(id=286, in='input', out=['const_logic_wrapper_input_0'], reg=False),
#  288: Wire(id=288, in='input', out=['const_logic_wrapper_input_2'], reg=False),
#  289: Wire(id=289, in='input', out=['const_logic_wrapper_input_3'], reg=False),
#  290: Wire(id=290, in='input', out=['const_logic_wrapper_input_4'], reg=False),
#  292: Wire(id=292, in='input', out=['const_logic_wrapper_input_6'], reg=False),
#  293: Wire(id=293, in='input', out=['const_logic_wrapper_input_7'], reg=False),
#  295: Wire(id=295, in='input', out=['const_logic_wrapper_input_9'], reg=False),
#  16: Wire(id=16, in='const_arith_wrapper_output_0', out=['output'], reg=False),
#  17: Wire(id=17, in='const_arith_wrapper_output_1', out=['output', 'const_concat_repl_wrapper_input_8'], reg=False),
#  18: Wire(id=18, in='const_arith_wrapper_output_2', out=['output'], reg=False),
#  19: Wire(id=19, in='const_arith_wrapper_output_3', out=['output'], reg=False),
#  20: Wire(id=20, in='const_arith_wrapper_output_4', out=['output'], reg=False),
#  21: Wire(id=21, in='const_arith_wrapper_output_5', out=['output'], reg=False),
#  22: Wire(id=22, in='const_arith_wrapper_output_6', out=['output'], reg=False),
#  23: Wire(id=23, in='const_arith_wrapper_output_7', out=['output'], reg=False),
#  24: Wire(id=24, in='const_arith_wrapper_output_8', out=['output'], reg=False),
#  25: Wire(id=25, in='const_arith_wrapper_output_9', out=['output'], reg=False),
#  26: Wire(id=26, in='const_arith_wrapper_output_10', out=['output'], reg=False),
#  27: Wire(id=27, in='const_arith_wrapper_output_11', out=['output'], reg=False),
#  28: Wire(id=28, in='const_arith_wrapper_output_12', out=['output'], reg=False),
#  29: Wire(id=29, in='const_arith_wrapper_output_13', out=['output'], reg=False),
#  30: Wire(id=30, in='const_arith_wrapper_output_14', out=['output', 'const_conditional_wrapper_input_17'], reg=False),
#  31: Wire(id=31, in='const_arith_wrapper_output_15', out=['output'], reg=False),
#  32: Wire(id=32, in='const_arith_wrapper_output_16', out=['output'], reg=False),
#  33: Wire(id=33, in='const_arith_wrapper_output_17', out=['output'], reg=False),
#  34: Wire(id=34, in='const_arith_wrapper_output_18', out=['output', 'const_nested_wrapper_input_11'], reg=False),
#  35: Wire(id=35, in='const_arith_wrapper_output_19', out=['output'], reg=False),
#  36: Wire(id=36, in='const_arith_wrapper_output_20', out=['output'], reg=False),
#  37: Wire(id=37, in='const_arith_wrapper_output_21', out=['output'], reg=False),
#  38: Wire(id=38, in='const_arith_wrapper_output_22', out=['output'], reg=False),
#  39: Wire(id=39, in='const_arith_wrapper_output_23', out=['output'], reg=False),
#  40: Wire(id=40, in='const_arith_wrapper_output_24', out=['output'], reg=False),
#  41: Wire(id=41, in='const_arith_wrapper_output_25', out=['output'], reg=False),
#  42: Wire(id=42, in='const_arith_wrapper_output_26', out=['output'], reg=False),
#  43: Wire(id=43, in='const_arith_wrapper_output_27', out=['output'], reg=False),
#  44: Wire(id=44, in='const_arith_wrapper_output_28', out=['output'], reg=False),
#  45: Wire(id=45, in='const_arith_wrapper_output_29', out=['output'], reg=False),
#  46: Wire(id=46, in='const_arith_wrapper_output_30', out=['output'], reg=False),
#  47: Wire(id=47, in='const_arith_wrapper_output_31', out=['output'], reg=False),
#  48: Wire(id=48, in='const_arith_wrapper_output_32', out=['output'], reg=False),
#  49: Wire(id=49, in='const_arith_wrapper_output_33', out=['output', 'const_partselect_wrapper_input_15'], reg=False),
#  50: Wire(id=50, in='const_arith_wrapper_output_34', out=['output', 'const_shift_wrapper_input_1'], reg=False),
#  51: Wire(id=51, in='const_arith_wrapper_output_35', out=['output'], reg=False),
#  52: Wire(id=52, in='const_arith_wrapper_output_36', out=['output'], reg=False),
#  53: Wire(id=53, in='const_arith_wrapper_output_37', out=['output'], reg=False),
#  54: Wire(id=54, in='const_arith_wrapper_output_38', out=['output'], reg=False),
#  55: Wire(id=55, in='const_arith_wrapper_output_39', out=['output'], reg=False),
#  67: Wire(id=67, in='const_shift_wrapper_output_0', out=['output'], reg=True),
#  68: Wire(id=68, in='const_shift_wrapper_output_1', out=['output'], reg=True),
#  69: Wire(id=69, in='const_shift_wrapper_output_2', out=['output'], reg=True),
#  70: Wire(id=70, in='const_shift_wrapper_output_3', out=['output'], reg=True),
#  71: Wire(id=71, in='const_shift_wrapper_output_4', out=['output'], reg=True),
#  72: Wire(id=72, in='const_shift_wrapper_output_5', out=['output'], reg=True),
#  73: Wire(id=73, in='const_shift_wrapper_output_6', out=['output'], reg=True),
#  74: Wire(id=74, in='const_shift_wrapper_output_7', out=['output'], reg=True),
#  75: Wire(id=75, in='const_shift_wrapper_output_8', out=['output'], reg=True),
#  76: Wire(id=76, in='const_shift_wrapper_output_9', out=['output'], reg=True),
#  77: Wire(id=77, in='const_shift_wrapper_output_10', out=['output'], reg=True),
#  78: Wire(id=78, in='const_shift_wrapper_output_11', out=['output'], reg=True),
#  79: Wire(id=79, in='const_shift_wrapper_output_12', out=['output'], reg=True),
#  80: Wire(id=80, in='const_shift_wrapper_output_13', out=['output'], reg=True),
#  81: Wire(id=81, in='const_shift_wrapper_output_14', out=['output'], reg=True),
#  82: Wire(id=82, in='const_shift_wrapper_output_15', out=['output'], reg=True),
#  83: Wire(id=83, in='const_shift_wrapper_output_16', out=['output'], reg=True),
#  84: Wire(id=84, in='const_shift_wrapper_output_17', out=['output'], reg=True),
#  85: Wire(id=85, in='const_shift_wrapper_output_18', out=['output', 'const_arith_wrapper_input_6'], reg=True),
#  86: Wire(id=86, in='const_shift_wrapper_output_19', out=['output'], reg=True),
#  87: Wire(id=87, in='const_shift_wrapper_output_20', out=['output'], reg=True),
#  88: Wire(id=88, in='const_shift_wrapper_output_21', out=['output'], reg=True),
#  89: Wire(id=89, in='const_shift_wrapper_output_22', out=['output'], reg=True),
#  90: Wire(id=90, in='const_shift_wrapper_output_23', out=['output'], reg=True),
#  118: Wire(id=118, in='const_nested_wrapper_output_0', out=['output'], reg=False),
#  119: Wire(id=119, in='const_nested_wrapper_output_1', out=['output'], reg=False),
#  120: Wire(id=120, in='const_nested_wrapper_output_2', out=['output', 'const_concat_repl_wrapper_input_7'], reg=False),
#  121: Wire(id=121, in='const_nested_wrapper_output_3', out=['output'], reg=False),
#  122: Wire(id=122, in='const_nested_wrapper_output_4', out=['output', 'const_logic_wrapper_input_1'], reg=False),
#  123: Wire(id=123, in='const_nested_wrapper_output_5', out=['output', 'const_conditional_wrapper_input_13'], reg=False),
#  124: Wire(id=124, in='const_nested_wrapper_output_6', out=['output'], reg=False),
#  125: Wire(id=125, in='const_nested_wrapper_output_7', out=['output'], reg=False),
#  146: Wire(id=146, in='const_partselect_wrapper_output_0', out=['output'], reg=False),
#  147: Wire(id=147, in='const_partselect_wrapper_output_1', out=['output', 'const_reduce_wrapper_input_2'], reg=False),
#  148: Wire(id=148, in='const_partselect_wrapper_output_2', out=['output', 'const_compare_wrapper_input_17'], reg=False),
#  149: Wire(id=149, in='const_partselect_wrapper_output_3', out=['output'], reg=False),
#  150: Wire(id=150, in='const_partselect_wrapper_output_4', out=['output'], reg=False),
#  151: Wire(id=151, in='const_partselect_wrapper_output_5', out=['output'], reg=False),
#  152: Wire(id=152, in='const_partselect_wrapper_output_6', out=['output'], reg=False),
#  153: Wire(id=153, in='const_partselect_wrapper_output_7', out=['output'], reg=False),
#  178: Wire(id=178, in='const_compare_wrapper_output_0', out=['output'], reg=True),
#  179: Wire(id=179, in='const_compare_wrapper_output_1', out=['output'], reg=True),
#  180: Wire(id=180, in='const_compare_wrapper_output_2', out=['output'], reg=True),
#  181: Wire(id=181, in='const_compare_wrapper_output_3', out=['output', 'const_partselect_wrapper_input_14'], reg=True),
#  182: Wire(id=182, in='const_compare_wrapper_output_4', out=['output'], reg=True),
#  183: Wire(id=183, in='const_compare_wrapper_output_5', out=['output'], reg=True),
#  184: Wire(id=184, in='const_compare_wrapper_output_6', out=['output'], reg=True),
#  185: Wire(id=185, in='const_compare_wrapper_output_7', out=['output'], reg=True),
#  190: Wire(id=190, in='const_reduce_wrapper_output_0', out=['output'], reg=False),
#  191: Wire(id=191, in='const_reduce_wrapper_output_1', out=['output'], reg=False),
#  192: Wire(id=192, in='const_reduce_wrapper_output_2', out=['output'], reg=False),
#  193: Wire(id=193, in='const_reduce_wrapper_output_3', out=['output'], reg=False),
#  194: Wire(id=194, in='const_reduce_wrapper_output_4', out=['output'], reg=False),
#  195: Wire(id=195, in='const_reduce_wrapper_output_5', out=['output'], reg=False),
#  206: Wire(id=206, in='const_concat_repl_wrapper_output_0', out=['output', 'const_shift_wrapper_input_0'], reg=False),
#  207: Wire(id=207, in='const_concat_repl_wrapper_output_1', out=['output'], reg=False),
#  208: Wire(id=208, in='const_concat_repl_wrapper_output_2', out=['output'], reg=False),
#  209: Wire(id=209, in='const_concat_repl_wrapper_output_3', out=['output'], reg=False),
#  210: Wire(id=210, in='const_concat_repl_wrapper_output_4', out=['output'], reg=False),
#  211: Wire(id=211, in='const_concat_repl_wrapper_output_5', out=['output'], reg=False),
#  212: Wire(id=212, in='const_concat_repl_wrapper_output_6', out=['output'], reg=False),
#  213: Wire(id=213, in='const_concat_repl_wrapper_output_7', out=['output'], reg=False),
#  214: Wire(id=214, in='const_concat_repl_wrapper_output_8', out=['output'], reg=False),
#  215: Wire(id=215, in='const_concat_repl_wrapper_output_9', out=['output', 'const_logic_wrapper_input_8'], reg=False),
#  216: Wire(id=216, in='const_concat_repl_wrapper_output_10', out=['output'], reg=False),
#  217: Wire(id=217, in='const_concat_repl_wrapper_output_11', out=['output'], reg=False),
#  218: Wire(id=218, in='const_concat_repl_wrapper_output_12', out=['output'], reg=False),
#  219: Wire(id=219, in='const_concat_repl_wrapper_output_13', out=['output'], reg=False),
#  220: Wire(id=220, in='const_concat_repl_wrapper_output_14', out=['output'], reg=False),
#  221: Wire(id=221, in='const_concat_repl_wrapper_output_15', out=['output', 'const_partselect_wrapper_input_11'], reg=False),
#  222: Wire(id=222, in='const_concat_repl_wrapper_output_16', out=['output'], reg=False),
#  223: Wire(id=223, in='const_concat_repl_wrapper_output_17', out=['output'], reg=False),
#  224: Wire(id=224, in='const_concat_repl_wrapper_output_18', out=['output'], reg=False),
#  225: Wire(id=225, in='const_concat_repl_wrapper_output_19', out=['output'], reg=False),
#  226: Wire(id=226, in='const_concat_repl_wrapper_output_20', out=['output'], reg=False),
#  227: Wire(id=227, in='const_concat_repl_wrapper_output_21', out=['output'], reg=False),
#  262: Wire(id=262, in='const_conditional_wrapper_output_0', out=['output'], reg=False),
#  263: Wire(id=263, in='const_conditional_wrapper_output_1', out=['output'], reg=False),
#  264: Wire(id=264, in='const_conditional_wrapper_output_2', out=['output'], reg=False),
#  265: Wire(id=265, in='const_conditional_wrapper_output_3', out=['output'], reg=False),
#  266: Wire(id=266, in='const_conditional_wrapper_output_4', out=['output'], reg=False),
#  267: Wire(id=267, in='const_conditional_wrapper_output_5', out=['output'], reg=False),
#  268: Wire(id=268, in='const_conditional_wrapper_output_6', out=['output'], reg=False),
#  269: Wire(id=269, in='const_conditional_wrapper_output_7', out=['output'], reg=False),
#  270: Wire(id=270, in='const_conditional_wrapper_output_8', out=['output'], reg=False),
#  271: Wire(id=271, in='const_conditional_wrapper_output_9', out=['output'], reg=False),
#  272: Wire(id=272, in='const_conditional_wrapper_output_10', out=['output'], reg=False),
#  273: Wire(id=273, in='const_conditional_wrapper_output_11', out=['output'], reg=False),
#  274: Wire(id=274, in='const_conditional_wrapper_output_12', out=['output'], reg=False),
#  275: Wire(id=275, in='const_conditional_wrapper_output_13', out=['output'], reg=False),
#  276: Wire(id=276, in='const_conditional_wrapper_output_14', out=['output'], reg=False),
#  277: Wire(id=277, in='const_conditional_wrapper_output_15', out=['output'], reg=False),
#  278: Wire(id=278, in='const_conditional_wrapper_output_16', out=['output'], reg=False),
#  279: Wire(id=279, in='const_conditional_wrapper_output_17', out=['output'], reg=False),
#  280: Wire(id=280, in='const_conditional_wrapper_output_18', out=['output'], reg=False),
#  281: Wire(id=281, in='const_conditional_wrapper_output_19', out=['output'], reg=False),
#  282: Wire(id=282, in='const_conditional_wrapper_output_20', out=['output'], reg=False),
#  283: Wire(id=283, in='const_conditional_wrapper_output_21', out=['output', 'const_partselect_wrapper_input_7'], reg=False),
#  284: Wire(id=284, in='const_conditional_wrapper_output_22', out=['output', 'const_logic_wrapper_input_5'], reg=False),
#  285: Wire(id=285, in='const_conditional_wrapper_output_23', out=['output'], reg=False),
#  296: Wire(id=296, in='const_logic_wrapper_output_0', out=['output', 'const_compare_wrapper_input_1'], reg=True),
#  297: Wire(id=297, in='const_logic_wrapper_output_1', out=['output'], reg=True),
#  298: Wire(id=298, in='const_logic_wrapper_output_2', out=['output'], reg=True),
#  299: Wire(id=299, in='const_logic_wrapper_output_3', out=['output'], reg=True),
#  300: Wire(id=300, in='const_logic_wrapper_output_4', out=['output'], reg=True),
#  301: Wire(id=301, in='const_logic_wrapper_output_5', out=['output'], reg=True),
#  302: Wire(id=302, in='const_logic_wrapper_output_6', out=['output'], reg=True),
#  303: Wire(id=303, in='const_logic_wrapper_output_7', out=['output', 'const_reduce_wrapper_input_3'], reg=True),
#  304: Wire(id=304, in='const_logic_wrapper_output_8', out=['output'], reg=True),
#  305: Wire(id=305, in='const_logic_wrapper_output_9', out=['output'], reg=True),
#  306: Wire(id=306, in='const_logic_wrapper_output_10', out=['output'], reg=True),
#  307: Wire(id=307, in='const_logic_wrapper_output_11', out=['output'], reg=True),
#  308: Wire(id=308, in='const_logic_wrapper_output_12', out=['output'], reg=True),
#  309: Wire(id=309, in='const_logic_wrapper_output_13', out=['output'], reg=True),
#  310: Wire(id=310, in='const_logic_wrapper_output_14', out=['output', 'const_conditional_wrapper_input_0'], reg=True),
#  311: Wire(id=311, in='const_logic_wrapper_output_15', out=['output'], reg=True),
#  312: Wire(id=312, in='const_logic_wrapper_output_16', out=['output'], reg=True),
#  313: Wire(id=313, in='const_logic_wrapper_output_17', out=['output'], reg=True),
#  314: Wire(id=314, in='const_logic_wrapper_output_18', out=['output'], reg=True)}

# %%
# test_fuzz.linear_rewire()
test_fuzz.generate_top_module()
# Out:
# '// Auto-generated Top Module for flattened IO\n`include "const_arith_wrapper.sv"\n`include "const_compare_wrapper.sv"\n`include "const_concat_repl_wrapper.sv"\n`include "const_conditional_wrapper.sv"\n`include "const_logic_wrapper.sv"\n`include "const_nested_wrapper.sv"\n`include "const_partselect_wrapper.sv"\n`include "const_reduce_wrapper.sv"\n`include "const_shift_wrapper.sv"\n\nmodule top (\n    input  wire clk,\n    input  wire [138:0] in_flat,\n    output wire [158:0] out_flat\n);\n\n// Per-module I/O buses\nwire [15:0] const_arith_wrapper_in_flat;\nwire [39:0] const_arith_wrapper_out_flat;\nwire [23:0] const_compare_wrapper_in_flat;\nwire [7:0] const_compare_wrapper_out_flat;\nwire [9:0] const_concat_repl_wrapper_in_flat;\nwire [21:0] const_concat_repl_wrapper_out_flat;\nwire [33:0] const_conditional_wrapper_in_flat;\nwire [23:0] const_conditional_wrapper_out_flat;\nwire [9:0] const_logic_wrapper_in_flat;\nwire [18:0] const_logic_wrapper_out_flat;\nwire [26:0] const_nested_wrapper_in_flat;\nwire [7:0] const_nested_wrapper_out_flat;\nwire [19:0] const_partselect_wrapper_in_flat;\nwire [7:0] const_partselect_wrapper_out_flat;\nwire [3:0] const_reduce_wrapper_in_flat;\nwire [5:0] const_reduce_wrapper_out_flat;\nwire [10:0] const_shift_wrapper_in_flat;\nwire [23:0] const_shift_wrapper_out_flat;\n\n// Registered output shadows for looped modules\nreg [39:0] const_arith_wrapper_out_reg;\nalways @(posedge clk) const_arith_wrapper_out_reg <= const_arith_wrapper_out_flat;\nreg [23:0] const_conditional_wrapper_out_reg;\nalways @(posedge clk) const_conditional_wrapper_out_reg <= const_conditional_wrapper_out_flat;\nreg [7:0] const_partselect_wrapper_out_reg;\nalways @(posedge clk) const_partselect_wrapper_out_reg <= const_partselect_wrapper_out_flat;\n\n// Initialize registered outputs to zero for simulation\ninitial begin\n    const_arith_wrapper_out_reg = 40\'b0;\n    const_conditional_wrapper_out_reg = 24\'b0;\n    const_partselect_wrapper_out_reg = 8\'b0;\nend\n\n// External inputs to module inputs\nassign const_compare_wrapper_in_flat[0] = in_flat[0];\nassign const_compare_wrapper_in_flat[1] = in_flat[1];\nassign const_compare_wrapper_in_flat[2] = in_flat[2];\nassign const_compare_wrapper_in_flat[3] = in_flat[3];\nassign const_compare_wrapper_in_flat[4] = in_flat[4];\nassign const_compare_wrapper_in_flat[5] = in_flat[5];\nassign const_compare_wrapper_in_flat[6] = in_flat[6];\nassign const_compare_wrapper_in_flat[7] = in_flat[7];\nassign const_compare_wrapper_in_flat[8] = in_flat[8];\nassign const_compare_wrapper_in_flat[9] = in_flat[9];\nassign const_compare_wrapper_in_flat[10] = in_flat[10];\nassign const_compare_wrapper_in_flat[11] = in_flat[11];\nassign const_compare_wrapper_in_flat[12] = in_flat[12];\nassign const_compare_wrapper_in_flat[13] = in_flat[13];\nassign const_compare_wrapper_in_flat[14] = in_flat[14];\nassign const_compare_wrapper_in_flat[15] = in_flat[15];\nassign const_compare_wrapper_in_flat[17] = in_flat[16];\nassign const_compare_wrapper_in_flat[18] = in_flat[17];\nassign const_compare_wrapper_in_flat[20] = in_flat[18];\nassign const_compare_wrapper_in_flat[21] = in_flat[19];\nassign const_compare_wrapper_in_flat[22] = in_flat[20];\nassign const_compare_wrapper_in_flat[23] = in_flat[21];\nassign const_nested_wrapper_in_flat[0] = in_flat[22];\nassign const_nested_wrapper_in_flat[1] = in_flat[23];\nassign const_nested_wrapper_in_flat[2] = in_flat[24];\nassign const_nested_wrapper_in_flat[3] = in_flat[25];\nassign const_nested_wrapper_in_flat[4] = in_flat[26];\nassign const_nested_wrapper_in_flat[5] = in_flat[27];\nassign const_nested_wrapper_in_flat[6] = in_flat[28];\nassign const_nested_wrapper_in_flat[7] = in_flat[29];\nassign const_nested_wrapper_in_flat[9] = in_flat[30];\nassign const_nested_wrapper_in_flat[10] = in_flat[31];\nassign const_nested_wrapper_in_flat[11] = in_flat[32];\nassign const_nested_wrapper_in_flat[12] = in_flat[33];\nassign const_nested_wrapper_in_flat[13] = in_flat[34];\nassign cons ...

# %%
test_fuzz.module_tree
# Out:
# {'const_compare_wrapper': {'depth': 4,
#   'tree': 4,
#   'children': ['const_conditional_wrapper', 'const_partselect_wrapper'],
#   'parents': ['const_shift_wrapper', 'const_concat_repl_wrapper'],
#   'loops': []},
#  'const_nested_wrapper': {'depth': 2,
#   'tree': 4,
#   'children': ['const_reduce_wrapper', 'const_arith_wrapper'],
#   'parents': ['const_shift_wrapper'],
#   'loops': []},
#  'const_reduce_wrapper': {'depth': 4,
#   'tree': 4,
#   'children': ['const_concat_repl_wrapper'],
#   'parents': ['const_shift_wrapper',
#    'const_logic_wrapper',
#    'const_nested_wrapper'],
#   'loops': []},
#  'const_partselect_wrapper': {'depth': 5,
#   'tree': 4,
#   'children': ['const_logic_wrapper'],
#   'parents': ['const_shift_wrapper',
#    'const_logic_wrapper',
#    'const_compare_wrapper'],
#   'loops': ['loop_2']},
#  'const_shift_wrapper': {'depth': 1,
#   'tree': 4,
#   'children': ['const_nested_wrapper',
#    'const_arith_wrapper',
#    'const_compare_wrapper',
#    'const_partselect_wrapper',
#    'const_reduce_wrapper',
#    'const_logic_wrapper'],
#   'parents': ['const_arith_wrapper'],
#   'loops': ['loop_0']},
#  'const_logic_wrapper': {'depth': 3,
#   'tree': 4,
#   'children': ['const_partselect_wrapper', 'const_reduce_wrapper'],
#   'parents': ['const_shift_wrapper', 'const_partselect_wrapper'],
#   'loops': ['loop_2']},
#  'const_conditional_wrapper': {'depth': 5,
#   'tree': 4,
#   'children': ['const_concat_repl_wrapper'],
#   'parents': ['const_concat_repl_wrapper', 'const_compare_wrapper'],
#   'loops': ['loop_1']},
#  'const_arith_wrapper': {'depth': 2,
#   'tree': 4,
#   'children': ['const_shift_wrapper'],
#   'parents': ['const_shift_wrapper', 'const_nested_wrapper'],
#   'loops': ['loop_0']},
#  'const_concat_repl_wrapper': {'depth': 4,
#   'tree': 4,
#   'children': ['const_conditional_wrapper', 'const_compare_wrapper'],
#   'parents': ['const_conditional_wrapper', 'const_reduce_wrapper'],
#   'loops': ['loop_1']}}

# %%
test_fuzz.all_wires
# Out:
# {0: Wire(id=0, in='input', out=['subtractor_wrapper_input_0'], reg=False),
#  1: Wire(id=1, in='input', out=['subtractor_wrapper_input_1'], reg=False),
#  3: Wire(id=3, in='input', out=['subtractor_wrapper_input_3'], reg=False),
#  7: Wire(id=7, in='input', out=['multiplier_wrapper_input_0'], reg=False),
#  8: Wire(id=8, in='input', out=['multiplier_wrapper_input_1'], reg=False),
#  10: Wire(id=10, in='input', out=['multiplier_wrapper_input_3'], reg=False),
#  17: Wire(id=17, in='input', out=['adder_wrapper_input_1'], reg=False),
#  18: Wire(id=18, in='input', out=['adder_wrapper_input_2'], reg=False),
#  19: Wire(id=19, in='input', out=['adder_wrapper_input_3'], reg=False),
#  4: Wire(id=4, in='subtractor_wrapper_output_0', out=['output', 'multiplier_wrapper_input_2'], reg=False),
#  5: Wire(id=5, in='subtractor_wrapper_output_1', out=['output'], reg=False),
#  6: Wire(id=6, in='subtractor_wrapper_output_2', out=['output'], reg=False),
#  11: Wire(id=11, in='multiplier_wrapper_output_0', out=['output'], reg=False),
#  12: Wire(id=12, in='multiplier_wrapper_output_1', out=['output'], reg=False),
#  13: Wire(id=13, in='multiplier_wrapper_output_2', out=['output'], reg=False),
#  14: Wire(id=14, in='multiplier_wrapper_output_3', out=['output', 'adder_wrapper_input_0'], reg=False),
#  15: Wire(id=15, in='multiplier_wrapper_output_4', out=['output'], reg=False),
#  20: Wire(id=20, in='adder_wrapper_output_0', out=['output'], reg=True),
#  21: Wire(id=21, in='adder_wrapper_output_1', out=['output', 'subtractor_wrapper_input_2'], reg=True),
#  22: Wire(id=22, in='adder_wrapper_output_2', out=['output'], reg=True)}

# %%
test_fuzz.visualize_graph_no_ext_out()

# %%
test_fuzz.module_tree
# Out:
# {'subtractor_wrapper': {'depth': 0,
#   'tree': 0,
#   'children': ['multiplier_wrapper', 'adder_wrapper'],
#   'parents': [],
#   'loops': []},
#  'multiplier_wrapper': {'depth': 1,
#   'tree': 0,
#   'children': ['adder_wrapper'],
#   'parents': ['subtractor_wrapper'],
#   'loops': []},
#  'adder_wrapper': {'depth': 2,
#   'tree': 0,
#   'children': [],
#   'parents': ['multiplier_wrapper', 'subtractor_wrapper'],
#   'loops': []}}

# %%
test_fuzz.all_wires
# Out:
# {7: Wire(id=7, in='input', out=['multiplier_wrapper_input_0'], reg=False),
#  8: Wire(id=8, in='input', out=['multiplier_wrapper_input_1'], reg=False),
#  9: Wire(id=9, in='input', out=['multiplier_wrapper_input_2'], reg=False),
#  16: Wire(id=16, in='input', out=['adder_wrapper_input_0'], reg=False),
#  18: Wire(id=18, in='input', out=['adder_wrapper_input_2'], reg=False),
#  4: Wire(id=4, in='subtractor_wrapper_output_0', out=['output'], reg=False),
#  5: Wire(id=5, in='subtractor_wrapper_output_1', out=['output'], reg=False),
#  6: Wire(id=6, in='subtractor_wrapper_output_2', out=['output'], reg=False),
#  11: Wire(id=11, in='multiplier_wrapper_output_0', out=['output'], reg=False),
#  12: Wire(id=12, in='multiplier_wrapper_output_1', out=['output', 'subtractor_wrapper_input_0'], reg=False),
#  13: Wire(id=13, in='multiplier_wrapper_output_2', out=['output', 'subtractor_wrapper_input_2', 'adder_wrapper_input_1'], reg=False),
#  14: Wire(id=14, in='multiplier_wrapper_output_3', out=['output', 'adder_wrapper_input_3'], reg=False),
#  15: Wire(id=15, in='multiplier_wrapper_output_4', out=['output'], reg=False),
#  20: Wire(id=20, in='adder_wrapper_output_0', out=['output', 'subtractor_wrapper_input_1'], reg=True),
#  21: Wire(id=21, in='adder_wrapper_output_1', out=['output', 'subtractor_wrapper_input_3'], reg=True),
#  22: Wire(id=22, in='adder_wrapper_output_2', out=['output', 'multiplier_wrapper_input_3'], reg=True)}

# %%
test_fuzz.mod_IO
# Out:
# {'subtractor_wrapper': {'inputs': {11, 21}, 'outputs': {4, 5, 6}},
#  'multiplier_wrapper': {'inputs': {7, 8, 9, 22},
#   'outputs': {11, 12, 13, 14, 15}},
#  'adder_wrapper': {'inputs': {13, 14, 15, 16}, 'outputs': {20, 21, 22}}}

# %%
test_fuzz.loops
# Out:
# {'loop_0': ['multiplier_wrapper', 'adder_wrapper', 'multiplier_wrapper'],
#  'loop_1': ['multiplier_wrapper', 'subtractor_wrapper', 'multiplier_wrapper']}

# %%
verilog = test_fuzz.generate_top_module()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 verilog = test_fuzz.generate_top_module()
#
# Cell In[1], line 582, in Fuzz_Run.generate_top_module(self, top_name, output_path)
#     579     continue
#     580 dst_mod = self._mod_from_port(dst)
#     581 dst_bit = mod_in_order[dst_mod].index(
# --> 582     next(wid for wid in mod_IO[dst_mod]['inputs'] if dst in wire_map[wid].output)
#     583 )
#     585 # Use shadow reg for all outputs of registered modules
#     586 if src_mod in regged_modules:
#
# StopIteration:

# %%
print(verilog)
# Out:
# // Auto-generated Top Module for flattened IO
# `include "adder_wrapper.sv"
# `include "multiplier_wrapper.sv"
# `include "subtractor_wrapper.sv"
#
# module top (
#     input  wire clk,
#     input  wire [9:0] in_flat,
#     output wire [10:0] out_flat
# );
#
# // Per-module I/O buses
# wire [3:0] adder_wrapper_in_flat;
# wire [2:0] adder_wrapper_out_flat;
# wire [3:0] multiplier_wrapper_in_flat;
# wire [4:0] multiplier_wrapper_out_flat;
# wire [3:0] subtractor_wrapper_in_flat;
# wire [2:0] subtractor_wrapper_out_flat;
#
# // Registered output shadows for looped modules
# reg [2:0] adder_wrapper_out_reg;
# always @(posedge clk) adder_wrapper_out_reg <= adder_wrapper_out_flat;
#
# // External inputs to module inputs
# assign subtractor_wrapper_in_flat[0] = in_flat[0];
# assign subtractor_wrapper_in_flat[1] = in_flat[1];
# assign subtractor_wrapper_in_flat[2] = in_flat[2];
# assign subtractor_wrapper_in_flat[3] = in_flat[3];
# assign multiplier_wrapper_in_flat[0] = in_flat[4];
# assign multiplier_wrapper_in_flat[1] = in_flat[5];
# assign multiplier_wrapper_in_flat[2] = in_flat[6];
# assign adder_wrapper_in_flat[1] = in_flat[7];
# assign adder_wrapper_in_flat[2] = in_flat[8];
# assign adder_wrapper_in_flat[3] = in_flat[9];
#
# // Internal connections
# assign adder_wrapper_in_flat[0] = multiplier_wrapper_out_flat[3];
# assign multiplier_wrapper_in_flat[3] = adder_wrapper_out_reg[0];
#
# // External outputs
# assign out_flat[0] = subtractor_wrapper_out_flat[0];
# assign out_flat[1] = subtractor_wrapper_out_flat[1];
# assign out_flat[2] = subtractor_wrapper_out_flat[2];
# assign out_flat[3] = multiplier_wrapper_out_flat[0];
# assign out_flat[4] = multiplier_wrapper_out_flat[1];
# assign out_flat[5] = multiplier_wrapper_out_flat[2];
# assign out_flat[6] = multiplier_wrapper_out_flat[3];
# assign out_flat[7] = multiplier_wrapper_out_flat[4];
# assign out_flat[8] = adder_wrapper_out_reg[0];
# assign out_flat[9] = adder_wrapper_out_reg[1];
# assign out_flat[10] = adder_wrapper_out_reg[2];
#
# // Instantiate all module wrappers
# adder_wrapper u_adder_wrapper (
#     .in_flat(adder_wrapper_in_flat),
#     .out_flat(adder_wrapper_out_flat)
# );
# multiplier_wrapper u_multiplier_wrapper (
#     .in_flat(multiplier_wrapper_in_flat),
#     .out_flat(multiplier_wrapper_out_flat)
# );
# subtractor_wrapper u_subtractor_wrapper (
#     .in_flat(subtractor_wrapper_in_flat),
#     .out_flat(subtractor_wrapper_out_flat)
# );
# endmodule
